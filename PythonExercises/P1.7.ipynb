# %% [markdown]
# # Sequencias repetidas

# %%
seq_count = 0
i = 0
ListSeq = []

while True:
    seq = int(input("Enter the value: "))
    ListSeq.append(seq)

    if i >= 1:
        if nex1 == seq:
            seq_count+=1
    i +=1  
    nex1 = seq
    read -=1
    if seq == 0:
        break
print(f"\nThis sequence {ListSeq} \nHas {seq_count} sequence of igual numbers")
# Out:
# Enter the value:  7
# Enter the value:  5
# Enter the value:  5
# Enter the value:  3
# Enter the value:  8
# Enter the value:  8
# Enter the value:  8
# Enter the value:  8
# Enter the value:  2
# Enter the value:  2
# Enter the value:  0
# This sequence [7, 5, 5, 3, 8, 8, 8, 8, 2, 2, 0]
# Has 5 sequence of igual numbers
