# %%
from pytubefix import YouTube
from pytubefix.cli import on_progress
from pathlib import Path 


url = "https://www.youtube.com/watch?v=_hHzhijit-JK"
destino = path("pasta_video")
destino.mkdir(exist_ok=True)

yt = YouTube(url, on_progress_callback=on_progress)
print(f"Titulo: {yt.title}\nDuracao: {yt.length}s")

yt.streams.get_highest_resolution().download(output_path=destino)
print(f"Download concluido! Video salvo em: {destino}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pytubefix import YouTube
#       2 from pytubefix.cli import on_progress
#       3 from pathlib import Path
#
# ModuleNotFoundError: No module named 'pytubefix'

# %%
# !pip YouTube
# Out:
# ERROR: unknown command "YouTube"

# %%
from pytubefix import YouTube
from pytubefix.cli import on_progress
from pathlib import Path
import re

# Perguntar a URL
url = input("https://www.youtube.com/watch?v=4DJhvl-d6WU")

# Diretório de destino (Downloads)
destino = Path.home() / "Downloads"
destino.mkdir(exist_ok=True)

try:
    yt = YouTube(url, on_progress_callback=on_progress)
    print(f"Título: {yt.title}\nDuração: {yt.length}s")

    # Sanitizar nome do ficheiro
    titulo_seguro = re.sub(r'[\\/*?:"<>|]', "_", yt.title)

    # Escolher stream com vídeo+áudio (progressivo)
    stream = yt.streams.filter(progressive=True, file_extension="mp4").order_by("resolution").desc().first()
    
    if not stream:
        raise Exception("Nenhum stream progressivo encontrado!")

    # Fazer download
    stream.download(output_path=destino, filename=f"{titulo_seguro}.mp4")
    print(f"✅ Download concluído! Vídeo salvo em: {destino / (titulo_seguro + '.mp4')}")

except Exception as e:
    print(f"❌ Erro ao baixar vídeo: {e}")

input("Pressione ENTER para sair...")

# %%
# !jupyter nbconvert --to script script_download_youtube.ipynb
# Out:
# [NbConvertApp] Converting notebook script_download_youtube.ipynb to script
# [NbConvertApp] Writing 1771 bytes to script_download_youtube.py

# %%
# !pyinstaller --onefile script_download_youtube.py
# Out:
# 2900 INFO: PyInstaller: 6.16.0, contrib hooks: 2025.9
# 2901 INFO: Python: 3.13.0 (conda)
# 2966 INFO: Platform: Windows-11-10.0.26100-SP0
# 2966 INFO: Python environment: C:\Users\AbelCWanda\miniconda3
# 2967 INFO: wrote C:\Users\AbelCWanda\Documents\Courses\pydata-book\Practice\script_download_youtube.spec
# 2975 INFO: Module search paths (PYTHONPATH):
# ['C:\\Users\\AbelCWanda\\miniconda3\\Scripts\\pyinstaller.exe',
#  'C:\\Users\\AbelCWanda\\miniconda3\\python313.zip',
#  'C:\\Users\\AbelCWanda\\miniconda3\\DLLs',
#  'C:\\Users\\AbelCWanda\\miniconda3\\Lib',
#  'C:\\Users\\AbelCWanda\\miniconda3',
#  'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages',
#  'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\win32',
#  'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\win32\\lib',
#  'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\Pythonwin',
#  'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\setuptools\\_vendor',
#  'C:\\Users\\AbelCWanda\\Documents\\Courses\\pydata-book\\Practice']
# 6487 INFO: checking Analysis
# 6534 INFO: Building because C:\Users\AbelCWanda\Documents\Courses\pydata-book\Practice\script_download_youtube.py changed
# 6534 INFO: Looking for Python shared library...
# 6534 INFO: Using Python shared library: C:\Users\AbelCWanda\miniconda3\python313.dll
# 6534 INFO: Running Analysis Analysis-00.toc
# 6534 INFO: Target bytecode optimization level: 0
# 6534 INFO: Initializing module dependency graph...
# 6538 INFO: Initializing module graph hook caches...
# 6574 INFO: Analyzing modules for base_library.zip ...
# 16241 INFO: Processing standard module hook 'hook-encodings.py' from 'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\PyInstaller\\hooks'
# 19502 INFO: Processing standard module hook 'hook-heapq.py' from 'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\PyInstaller\\hooks'
# 21897 INFO: Processing standard module hook 'hook-pickle.py' from 'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\PyInstaller\\hooks'
# 24857 INFO: Caching module dependency graph...
# 24937 INFO: Analyzing C:\Users\AbelCWanda\Documents\Courses\pydata-book\Practice\script_download_youtube.py
# 26212 INFO: Processing standard module hook 'hook-xml.py' from 'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\PyInstaller\\hooks'
# 26257 INFO: Processing standard module hook 'hook-xml.etree.cElementTree.py' from 'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\PyInstaller\\hooks'
# 26760 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from 'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 26763 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 36839 INFO: Processing standard module hook 'hook-platform.py' from 'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\PyInstaller\\hooks'
# 36885 INFO: Processing standard module hook 'hook-_ctypes.py' from 'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\PyInstaller\\hooks'
# 37392 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from 'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\PyInstaller\\hooks'
# 42531 INFO: Processing module hooks (post-graph stage)...
# 42655 INFO: Performing binary vs. data reclassification (1 entries)
# 42657 INFO: Looking for ctypes DLLs
# 42685 INFO: Analyzing run-time hooks ...
# 42687 INFO: Including run-time hook 'pyi_rth_inspect.py' from 'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 42692 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from 'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 42697 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from 'C:\\Users\\AbelCWanda\\miniconda3\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 42710 INFO: Creating base_library.zip...
# 42754 INFO: Looking for dynamic libraries
# 43610 INFO: Extra DLL search directories (AddDllDirectory): []
# 43611 INFO: Extra DLL search directories (PATH): []
# 44641 INFO: Warnings written to C:\Users\AbelCWanda\Documents\Courses\pydata-book\Practice\build\script_download_youtube\warn-script_download_youtube.txt
# 44710 INFO: Graph cross-reference written to C:\Users\AbelCWanda\Documents\Courses\pydata-book\Practice\build\script_download_youtube\xref-script_download_youtube.html
# 44747 INFO: checking PYZ
# 44769 INFO: checking PKG
# 44797 INFO: Building because toc changed
# 44797 INFO: Building PKG (CArchive) script_download_youtube.pkg
# 49155 INFO: Building PKG (CArchive) script_download_youtube.pkg completed successfully.
# 49159 INFO: Bootloader C:\Users\AbelCWanda\miniconda3\Lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\run.exe
# 49159 INFO: checking EXE
# 49187 INFO: Building because toc changed
# 49187 INFO: Building EXE from EXE-00.toc
# 49189 INFO: Copying bootloader EXE to C:\Users\AbelCWanda\Documents\Courses\pydata-book\Practice\dist\script_download_youtube.exe
# 49295 INFO: Copying icon to EXE
# 49365 INFO: Copying 0 resources to EXE
# 49365 INFO: Embedding manifest in EXE
# 49433 INFO: Appending PKG archive to EXE
# 49571 INFO: Fixing EXE headers
# 52250 INFO: Building EXE from EXE-00.toc completed successfully.
# 52254 INFO: Build complete! The results are available in: C:\Users\AbelCWanda\Documents\Courses\pydata-book\Practice\dist
