# %% [markdown]
# ### Read 3 integers numbers and find the biggest and the smollest

# %%
numb1 = int(input("Insert number: "))
numb2 = int(input("Insert number: "))
numb3 = int(input("Insert number: "))


if numb1 > numb2:
    if numb1 > numb3:
        if numb2 > numb3:
            max_n = numb1
            min_n = numb3
        else:
            max_n = numb1
            min_n = numb2
    else:
        max_n = numb3
        min_n = numb2
else:
    if numb2 > numb3:
        if numb1 > numb3:
            max_n = numb2
            min_n = numb3
        else:
            max_n = numb2
            min_n = numb1
    else:
        max_n = numb3
        min_n = numb1
print("")
print(f"The Biggest: {max_n}\nThe Smallest: {min_n}")
# Out:
# Insert number:  -1
# Insert number:  4
# Insert number:  99
# The Biggest: 99
# The Smallest: -1
