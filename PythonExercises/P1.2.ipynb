# %% [markdown]
# ### Determine pot using (x**y)

# %%
base_x = float(input("insert base: "))
exp_n = int(input("insert exp: "))

pot = (base_x)**exp_n

print(f"{base_x} elevate to {exp_n} = {pot}")
# Out:
# insert base:  2
# insert exp:  3
# 2.0 elevate to 3 = 8.0
